# %%
import torchvision.datasets as datasets
import torchvision.transforms as transforms

# %%
save_path = "/Users/deveshshah/Documents/Programming/Out_Of_Distribution_Exploration/dataset/svhn/"

# %%
transform = transforms.Compose([transforms.ToTensor()])

# %%
# Stanford Cars - test set
svhn = datasets.SVHN(root=save_path, split="test", download=True, transform=transform)
# Out:
# 100%|██████████| 64.3M/64.3M [00:29<00:00, 2.17MB/s]

# %%
import os
import pandas as pd

# %%
all_images = os.listdir("/Users/deveshshah/Documents/Programming/Out_Of_Distribution_Exploration/dataset/standfordcars/images_resized")

# %%
len(all_images)
# Out:
# 8041

# %%
df = pd.DataFrame(all_images, columns=["image_path"])
df["stage"] = "test"
df["label"] = "ood_test"
df["id"] = "standfordcars_" + df.index.astype(str)

# %%
df = df[["id", "image_path", "label", "stage"]]

# %%
df.head()
# Out:
#                 id image_path     label stage
# 0  standfordcars_0  04354.jpg  ood_test  test
# 1  standfordcars_1  02725.jpg  ood_test  test
# 2  standfordcars_2  07885.jpg  ood_test  test
# 3  standfordcars_3  06543.jpg  ood_test  test
# 4  standfordcars_4  00132.jpg  ood_test  test

# %%
len(df), df["id"].nunique()
# Out:
# (8041, 8041)

# %%
df.to_csv("/Users/deveshshah/Documents/Programming/Out_Of_Distribution_Exploration/dataset/standfordcars/dataset.csv", index=False)
