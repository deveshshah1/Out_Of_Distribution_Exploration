# %%
import torchvision.datasets as datasets
import torchvision.transforms as transforms

# %%
save_path = "/Users/deveshshah/Documents/Programming/Out_Of_Distribution_Exploration/dataset/dtd/"

# %%
transform = transforms.Compose([transforms.ToTensor()])

# %%
# Stanford Cars - test set
dtd = datasets.DTD(root=save_path, split="test", download=True, transform=transform)
# Out:
# 100%|██████████| 625M/625M [04:08<00:00, 2.51MB/s]

# %%
import os
import pandas as pd

# %%
all_images = os.listdir("/Users/deveshshah/Documents/Programming/Out_Of_Distribution_Exploration/dataset/dtd/images_resized")

# %%
len(all_images)
# Out:
# 5641

# %%
df = pd.DataFrame(all_images, columns=["image_path"])
df["stage"] = "test"
df["label"] = "ood_test"
df["id"] = "dtd_" + df.index.astype(str)

# %%
df = df[["id", "image_path", "label", "stage"]]

# %%
df.head()
# Out:
#       id                  image_path     label stage
# 0  dtd_0    stained_stained_0124.jpg  ood_test  test
# 1  dtd_1  wrinkled_wrinkled_0038.jpg  ood_test  test
# 2  dtd_2    studded_studded_0194.jpg  ood_test  test
# 3  dtd_3        bumpy_bumpy_0197.jpg  ood_test  test
# 4  dtd_4      frilly_frilly_0089.jpg  ood_test  test

# %%
len(df), df["id"].nunique()
# Out:
# (5641, 5641)

# %%
df.to_csv("/Users/deveshshah/Documents/Programming/Out_Of_Distribution_Exploration/dataset/dtd/dataset.csv", index=False)
